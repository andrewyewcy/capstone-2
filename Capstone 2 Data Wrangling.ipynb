# %% [markdown]
# # Exploring Data available in Foundation App
#
# The data can be gathered from the FND mainnet subgraph API at: https://api.thegraph.com/subgraphs/name/f8n/fnd
#
# A total of 15 "Query" tables were found under the "Schema" of the FND mainnet subgraph.
#
# Out of 15, 9 of the "Query" tables are explored below to determine if enough data exists for the capstone project.

# %%
#import required packages
import requests
import json

import numpy as np
import pandas as pd

import pandas_profiling
from pandas_profiling import ProfileReport
#from pandas_profiling.utils.cache import cache_file

# %% [markdown]
# ## Account query

# %%
query  = """
{
    accounts(first:5, orderBy: netRevenueInETH, orderDirection: desc, where:{isAdmin :false})
    {id
    isAdmin
    netRevenueInETH
    netRevenuePendingInETH
    pendingWithdrawalAmountInETH}
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                              count unique  \
# id                               5      5
# isAdmin                          5      1
# netRevenueInETH                  5      5
# netRevenuePendingInETH           5      4
# pendingWithdrawalAmountInETH     5      1
#
#                                                                      top freq
# id                            0x484a12a27e8c95718e0b60d14369bfeaa426aff3    1
# isAdmin                                                            False    5
# netRevenueInETH                                                  63.9625    1
# netRevenuePendingInETH                                                 0    2
# pendingWithdrawalAmountInETH                                           0    5

# %% [markdown]
# ## Creator query

# %%
query  = """
{
    creators(first:5, orderBy: netRevenueInETH, orderDirection: desc)
    {
    id
    account
    netSalesInETH
    netSalesPendingInETH
    netRevenueInETH
    netRevenuePendingInETH
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                        count unique  \
# account                    5      1
# id                         5      5
# netRevenueInETH            5      5
# netRevenuePendingInETH     5      1
# netSalesInETH              5      5
# netSalesPendingInETH       5      1
#
#                                                                top freq
# account                                                         {}    5
# id                      0xf74d1224931afa9cf12d06092c1eb1818d1e255c    1
# netRevenueInETH                                             1890.4    1
# netRevenuePendingInETH                                           0    5
# netSalesInETH                                                 2224    1
# netSalesPendingInETH                                             0    5

# %% [markdown]
# ## NftContract

# %%
query  = """
{
    nftContracts(first:5)
    {
    id
    name
    symbol
    baseURI
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#         count unique                                         top freq
# baseURI     0      0                                         NaN  NaN
# id          5      5  0x01a3f8720bea1cbe02e580df45371b58351eabc1    1
# name        0      0                                         NaN  NaN
# symbol      0      0                                         NaN  NaN

# %% [markdown]
# ## Nft

# %%
query  = """
{
    nfts(first:5, orderBy: netSalesInETH, orderDirection: desc)
    {
    id
    nftContract

    tokenIPFSPath
    name
    description
    image
    creator
    dateMinted
    mintedTransfer
    owner
    ownedOrListedBy
    approvedSpender
    netSalesInETH
    netSalesPendingInETH
    netRevenueInETH
    netRevenuePendingInETH
    isFirstSale
    mostRecentAuction
    mostRecentActiveAuction
    latestFinalizedAuction
    tokenCreatorPaymentAddress
    percentSplit
    lastSalePriceInETH
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                            count unique  \
# approvedSpender                5      1
# creator                        5      1
# dateMinted                     5      5
# description                    0      0
# id                             5      5
# image                          0      0
# isFirstSale                    5      1
# lastSalePriceInETH             5      4
# latestFinalizedAuction         5      1
# mintedTransfer                 5      1
# mostRecentActiveAuction        5      1
# mostRecentAuction              5      1
# name                           0      0
# netRevenueInETH                5      4
# netRevenuePendingInETH         5      5
# netSalesInETH                  5      4
# netSalesPendingInETH           5      5
# nftContract                    5      1
# ownedOrListedBy                5      1
# owner                          5      1
# percentSplit                   0      0
# tokenCreatorPaymentAddress     0      0
# tokenIPFSPath                  5      5
#
#                                                                           top  \
# approvedSpender                                                            {}
# creator                                                                    {}
# dateMinted                                                         1618452786
# description                                                               NaN
# id                           0x3b3ee1931dc30c1957379fac9aba94d1c48a5405-24437
# image                                                                     NaN
# isFirstSale                                                             False
# lastSalePriceInETH                                                        350
# latestFinalizedAuction                                                     {}
# mintedTransfer                                                             {}
# mostRecentActiveAuction                                                    {}
# mostRecentAuction                                                          {}
# name                                                                      NaN
# netRevenueInETH                                                         297.5
# netRevenuePendingInETH                                           12677.174465
# netSalesInETH                                                             350
# netSalesPendingInETH                                               14914.3229
# nftContract                                                                {}
# ownedOrListedBy                                                            {}
# owner                                                                      {}
# percentSplit                                                              NaN
# tokenCreatorPaymentAddress                                                NaN
# tokenIPFSPath               QmNeqUFf3WKcXFEHgxFCrf3t8jrxyCkev6LBtRz78Ygq9u...
#
#                            freq
# approvedSpender               5
# creator                       5
# dateMinted                    1
# description                 NaN
# id                            1
# image                       NaN
# isFirstSale                   5
# lastSalePriceInETH            2
# latestFinalizedAuction        5
# mintedTransfer                5
# mostRecentActiveAuction       5
# mostRecentAuction             5
# name                        NaN
# netRevenueInETH               2
# netRevenuePendingInETH        1
# netSalesInETH                 2
# netSalesPendingInETH          1
# nftContract                   5
# ownedOrListedBy               5
# owner                         5
# percentSplit                NaN
# tokenCreatorPaymentAddress  NaN
# tokenIPFSPath                 1

# %% [markdown]
# ## Nft Transfer

# %%
query  = """
{
    nftTransfers(first:5)
    {
    id
    nft
    from
    to
    dateTransferred
    transactionHash
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                 count unique  \
# dateTransferred     5      5
# from                5      1
# id                  5      5
# nft                 5      1
# to                  5      1
# transactionHash     5      5
#
#                                                                top freq
# dateTransferred                                         1631965722    1
# from                                                            {}    5
# id               0x000018d26fc4895c49d2aec0b35e4d702e918bb11ff8...    1
# nft                                                             {}    5
# to                                                              {}    5
# transactionHash  0x000018d26fc4895c49d2aec0b35e4d702e918bb11ff8...    1

# %% [markdown]
# ## NftAccountApproval

# %%
query  = """
{
    nftAccountApprovals(first:5)
    {
    id
    nftContract
    owner
    spender
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#             count unique                                                top  \
# id              5      5  0x3b3ee1931dc30c1957379fac9aba94d1c48a5405-0x0...
# nftContract     5      1                                                 {}
# owner           5      1                                                 {}
# spender         5      1                                                 {}
#
#             freq
# id             1
# nftContract    5
# owner          5
# spender        5

# %% [markdown]
# ## NftMarketContract

# %%
query  = """
{
    nftMarketContracts(first:5)
    {
    id
    minBidIncrementInPercent
    maxBidIncrementRequirementInETH
    percentPrimaryFoundationFee
    percentSecondaryFoundationFee
    percentSecondaryCreatorFee
    duration
    extensionDuration
    dateGoLiveDate
    numberOfBidsPlaced
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                                 count unique  \
# dateGoLiveDate                      1      1
# duration                            1      1
# extensionDuration                   1      1
# id                                  1      1
# maxBidIncrementRequirementInETH     1      1
# minBidIncrementInPercent            1      1
# numberOfBidsPlaced                  1      1
# percentPrimaryFoundationFee         1      1
# percentSecondaryCreatorFee          1      1
# percentSecondaryFoundationFee       1      1
#
#                                                                         top  \
# dateGoLiveDate                                                            0
# duration                                                              86400
# extensionDuration                                                       900
# id                               0xcda72070e455bb31c7690a170224ce43623d0b6f
# maxBidIncrementRequirementInETH                                           0
# minBidIncrementInPercent                                                 10
# numberOfBidsPlaced                                                    98456
# percentPrimaryFoundationFee                                              15
# percentSecondaryCreatorFee                                               10
# percentSecondaryFoundationFee                                             5
#
#                                 freq
# dateGoLiveDate                     1
# duration                           1
# extensionDuration                  1
# id                                 1
# maxBidIncrementRequirementInETH    1
# minBidIncrementInPercent           1
# numberOfBidsPlaced                 1
# percentPrimaryFoundationFee        1
# percentSecondaryCreatorFee         1
# percentSecondaryFoundationFee      1

# %% [markdown]
# ## NftMarketAuction

# %%
query  = """
{
    nftMarketAuctions(first:5, orderBy: creatorRevenueInETH, orderDirection: desc, 
    where:{status:Open})
    {
    id
    nftMarketContract
    auctionId
    nft
    nftContract
    status
    seller
    dateCreated
    transactionHashCreated
    dateStarted
    dateEnding


    dateFinalized
    transactionHashCanceled
    reservePriceInETH
    initialBid
    highestBid
    creatorRevenueInETH
    foundationRevenueInETH
    ownerRevenueInETH
    duration
    extensionDuration
    isPrimarySale
    numberOfBids
    bidVolumeInETH
    }
}
"""
#[bids]
#    dateCancelled
#    cancelledReason

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                         count unique  \
# auctionId                   5      5
# bidVolumeInETH              5      1
# creatorRevenueInETH         0      0
# dateCreated                 5      5
# dateEnding                  0      0
# dateFinalized               0      0
# dateStarted                 0      0
# duration                    5      1
# extensionDuration           5      1
# foundationRevenueInETH      0      0
# highestBid                  0      0
# id                          5      5
# initialBid                  0      0
# isPrimarySale               5      1
# nft                         5      1
# nftContract                 5      1
# nftMarketContract           5      1
# numberOfBids                5      1
# ownerRevenueInETH           0      0
# reservePriceInETH           5      3
# seller                      5      1
# status                      5      1
# transactionHashCanceled     0      0
# transactionHashCreated      5      5
#
#                                                                        top  \
# auctionId                                                            99999
# bidVolumeInETH                                                           0
# creatorRevenueInETH                                                    NaN
# dateCreated                                                     1634158662
# dateEnding                                                             NaN
# dateFinalized                                                          NaN
# dateStarted                                                            NaN
# duration                                                             86400
# extensionDuration                                                      900
# foundationRevenueInETH                                                 NaN
# highestBid                                                             NaN
# id                        0xcda72070e455bb31c7690a170224ce43623d0b6f-99999
# initialBid                                                             NaN
# isPrimarySale                                                         True
# nft                                                                     {}
# nftContract                                                             {}
# nftMarketContract                                                       {}
# numberOfBids                                                             0
# ownerRevenueInETH                                                      NaN
# reservePriceInETH                                                      0.5
# seller                                                                  {}
# status                                                                Open
# transactionHashCanceled                                                NaN
# transactionHashCreated   0xb91395688369cc851b5add76dceef65619a9bfc2f4ee...
#
#                         freq
# auctionId                  1
# bidVolumeInETH             5
# creatorRevenueInETH      NaN
# dateCreated                1
# dateEnding               NaN
# dateFinalized            NaN
# dateStarted              NaN
# duration                   5
# extensionDuration          5
# foundationRevenueInETH   NaN
# highestBid               NaN
# id                         1
# initialBid               NaN
# isPrimarySale              5
# nft                        5
# nftContract                5
# nftMarketContract          5
# numberOfBids               5
# ownerRevenueInETH        NaN
# reservePriceInETH          2
# seller                     5
# status                     5
# transactionHashCanceled  NaN
# transactionHashCreated     1

# %% [markdown]
# ## NftMarketBid

# %%
query  = """
{
    nftMarketBids(first:5, orderBy: amountInETH, orderDirection: desc)
    {
    id
    nftMarketAuction
    nft
    bidder
    datePlaced
    transactionHashPlaced
    amountInETH
    status
    dateLeftActiveStatus
    transactionHashLeftActiveStatus
    seller
    extendedAuction
    outbidByBid
    bidThisOutbid
    }
}
"""

url = 'https://api.thegraph.com/subgraphs/name/f8n/fnd'
r = requests.post(url, json={'query': query})
#print(r.status_code)
#print(r.text)

# convert json into list
json_data = json.loads(r.text)
extracted_data = json_data['data'][list(json_data['data'].keys())[0]]

#create a empty dataframe to store the extracted data
# ref to https://www.kite.com/python/answers/how-to-create-an-empty-dataframe-with-column-names-in-python
df_column_names = list(extracted_data[0].keys())
wrangled_df = pd.DataFrame(columns = df_column_names)
#print(wrangled_df.head())

# store each entry from the extracted data into the empty data frame
for i in range(len(extracted_data)):
    wrangled_df = wrangled_df.append(extracted_data[i], ignore_index = True)
    
#profile_report = ProfileReport(wrangled_df, minimal = True)
#profile_report.to_notebook_iframe()
wrangled_df.describe().T
# Out:
#                                 count unique  \
# amountInETH                         5      5
# bidThisOutbid                       5      1
# bidder                              5      1
# dateLeftActiveStatus                5      5
# datePlaced                          5      5
# extendedAuction                     5      1
# id                                  5      5
# nft                                 5      1
# nftMarketAuction                    5      1
# outbidByBid                         4      1
# seller                              5      1
# status                              5      2
# transactionHashLeftActiveStatus     5      5
# transactionHashPlaced               5      5
#
#                                                                                top  \
# amountInETH                                                                   2224
# bidThisOutbid                                                                   {}
# bidder                                                                          {}
# dateLeftActiveStatus                                                    1618606455
# datePlaced                                                              1618603968
# extendedAuction                                                               True
# id                               0xcda72070e455bb31c7690a170224ce43623d0b6f-236...
# nft                                                                             {}
# nftMarketAuction                                                                {}
# outbidByBid                                                                     {}
# seller                                                                          {}
# status                                                                      Outbid
# transactionHashLeftActiveStatus  0xa0c34580aa1c16db491d7f42501a89c6a932b168816d...
# transactionHashPlaced            0x88dfe92ce544a74cc93a7d1ee6b4009eb1dcc841b8e5...
#
#                                 freq
# amountInETH                        1
# bidThisOutbid                      5
# bidder                             5
# dateLeftActiveStatus               1
# datePlaced                         1
# extendedAuction                    5
# id                                 1
# nft                                5
# nftMarketAuction                   5
# outbidByBid                        4
# seller                             5
# status                             4
# transactionHashLeftActiveStatus    1
# transactionHashPlaced              1
